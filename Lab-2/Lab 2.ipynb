# %%
Data Wrangling II
Create an “Academic performance” dataset of students and perform the following operations using
Python.
1. Scan all variables for missing values and inconsistencies. If there are missing values and/or
inconsistencies, use any of the suitable techniques to deal with them.
2. Scan all numeric variables for outliers. If there are outliers, use any of the suitable
techniques to deal with them.
3. Apply data transformations on at least one of the variables. The purpose of this
transformation should be one of the following reasons: to change the scale for better
understanding of the variable, to convert a non-linear relation into a linear one, or to
decrease the skewness and convert the distribution into a normal distribution.
Reason and document your approach properly.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("shradha.csv")

# %%
df
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0         62.0             NaN           90.0              NaN
# 1          NaN            74.0           87.0             81.0
# 2         65.0            76.0           61.0             72.0
# 3         68.0            78.0            NaN             80.0
# 4          NaN            75.0           63.0              NaN
# 5         81.0             NaN           58.0             70.0
# 6         78.0            78.0            NaN             81.0
# 7         84.0            77.0           61.0             76.0
# 8          NaN            86.0           71.0              NaN
# 9         80.0            87.0           85.0             71.0
# 10        77.0             NaN            NaN             79.0
# 11        60.0            80.0           67.0              NaN
# 12        60.0            73.0           71.0             73.0
# 13         NaN            83.0           50.0             77.0
# ...

# %%
df.isnull()
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0        False            True          False             True
# 1         True           False          False            False
# 2        False           False          False            False
# 3        False           False           True            False
# 4         True           False          False             True
# 5        False            True          False            False
# 6        False           False           True            False
# 7        False           False          False            False
# 8         True           False          False             True
# 9        False           False          False            False
# 10       False            True           True            False
# 11       False           False          False             True
# 12       False           False          False            False
# 13        True           False          False            False
# ...

# %%
series = pd.isnull(df["math score"])
df[series]
# Out:
#     math score  reading ascore  writing score  placement score  \
# 1          NaN            74.0           87.0             81.0
# 4          NaN            75.0           63.0              NaN
# 8          NaN            86.0           71.0              NaN
# 13         NaN            83.0           50.0             77.0
# 18         NaN            78.0           63.0              NaN
# 25         NaN            88.0           70.0             71.0
#
#     club join year  placement offer count  gender
# 1             2018                      2    male
# 4             2021                      1    male
# 8             2023                      1    male
# 13            2018                      2  female
# 18            2019                      1    male
# 25            2023                      1    male

# %%
df.notnull()
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0         True           False           True            False
# 1        False            True           True             True
# 2         True            True           True             True
# 3         True            True          False             True
# 4        False            True           True            False
# 5         True           False           True             True
# 6         True            True          False             True
# 7         True            True           True             True
# 8        False            True           True            False
# 9         True            True           True             True
# 10        True           False          False             True
# 11        True            True           True            False
# 12        True            True           True             True
# 13       False            True           True             True
# ...

# %%
series1 = pd.notnull(df["math score"])
df[series]
# Out:
#     math score  reading ascore  writing score  placement score  \
# 1          NaN            74.0           87.0             81.0
# 4          NaN            75.0           63.0              NaN
# 8          NaN            86.0           71.0              NaN
# 13         NaN            83.0           50.0             77.0
# 18         NaN            78.0           63.0              NaN
# 25         NaN            88.0           70.0             71.0
#
#     club join year  placement offer count  gender
# 1             2018                      2    male
# 4             2021                      1    male
# 8             2023                      1    male
# 13            2018                      2  female
# 18            2019                      1    male
# 25            2023                      1    male

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])
newdf = df
df
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0         62.0             NaN           90.0              NaN
# 1          NaN            74.0           87.0             81.0
# 2         65.0            76.0           61.0             72.0
# 3         68.0            78.0            NaN             80.0
# 4          NaN            75.0           63.0              NaN
# 5         81.0             NaN           58.0             70.0
# 6         78.0            78.0            NaN             81.0
# 7         84.0            77.0           61.0             76.0
# 8          NaN            86.0           71.0              NaN
# 9         80.0            87.0           85.0             71.0
# 10        77.0             NaN            NaN             79.0
# 11        60.0            80.0           67.0              NaN
# 12        60.0            73.0           71.0             73.0
# 13         NaN            83.0           50.0             77.0
# ...

# %%
missing_values = ["Na","na"]
df = pd.read_csv("shradha.csv",na_values = missing_values)
df
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0         62.0             NaN           90.0              NaN
# 1          NaN            74.0           87.0             81.0
# 2         65.0            76.0           61.0             72.0
# 3         68.0            78.0            NaN             80.0
# 4          NaN            75.0           63.0              NaN
# 5         81.0             NaN           58.0             70.0
# 6         78.0            78.0            NaN             81.0
# 7         84.0            77.0           61.0             76.0
# 8          NaN            86.0           71.0              NaN
# 9         80.0            87.0           85.0             71.0
# 10        77.0             NaN            NaN             79.0
# 11        60.0            80.0           67.0              NaN
# 12        60.0            73.0           71.0             73.0
# 13         NaN            83.0           50.0             77.0
# ...

# %%
ndf=df
ndf.fillna(0)
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0         62.0             0.0           90.0              0.0
# 1          0.0            74.0           87.0             81.0
# 2         65.0            76.0           61.0             72.0
# 3         68.0            78.0            0.0             80.0
# 4          0.0            75.0           63.0              0.0
# 5         81.0             0.0           58.0             70.0
# 6         78.0            78.0            0.0             81.0
# 7         84.0            77.0           61.0             76.0
# 8          0.0            86.0           71.0              0.0
# 9         80.0            87.0           85.0             71.0
# 10        77.0             0.0            0.0             79.0
# 11        60.0            80.0           67.0              0.0
# 12        60.0            73.0           71.0             73.0
# 13         0.0            83.0           50.0             77.0
# ...

# %%
m_v = df["math score"].mean()
df['math score'].fillna(value=m_v,inplace = True)
df
# Out:
# C:\Users\SHRADDHA\AppData\Local\Temp\ipykernel_35712\1082177283.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['math score'].fillna(value=m_v,inplace = True)
#     math score  reading ascore  writing score  placement score  \
# 0    62.000000             NaN           90.0              NaN
# 1    69.043478            74.0           87.0             81.0
# 2    65.000000            76.0           61.0             72.0
# 3    68.000000            78.0            NaN             80.0
# ...

# %%
ndf.replace(to_replace = np.nan,value = -99)
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0    62.000000           -99.0           90.0            -99.0
# 1    69.043478            74.0           87.0             81.0
# 2    65.000000            76.0           61.0             72.0
# 3    68.000000            78.0          -99.0             80.0
# 4    69.043478            75.0           63.0            -99.0
# 5    81.000000           -99.0           58.0             70.0
# 6    78.000000            78.0          -99.0             81.0
# 7    84.000000            77.0           61.0             76.0
# 8    69.043478            86.0           71.0            -99.0
# 9    80.000000            87.0           85.0             71.0
# 10   77.000000           -99.0          -99.0             79.0
# 11   60.000000            80.0           67.0            -99.0
# 12   60.000000            73.0           71.0             73.0
# 13   69.043478            83.0           50.0             77.0
# ...

# %%
ndf.dropna()
# Out:
#     math score  reading ascore  writing score  placement score  \
# 1    69.043478            74.0           87.0             81.0
# 2    65.000000            76.0           61.0             72.0
# 7    84.000000            77.0           61.0             76.0
# 9    80.000000            87.0           85.0             71.0
# 12   60.000000            73.0           71.0             73.0
# 13   69.043478            83.0           50.0             77.0
# 16   60.000000            83.0           59.0             75.0
# 17   82.000000            90.0           73.0             73.0
# 19   65.000000            83.0           82.0             77.0
# 22   63.000000            81.0           65.0             89.0
# 23   60.000000            88.0           56.0             87.0
# 24   86.000000            86.0           67.0             76.0
# 25   69.043478            88.0           70.0             71.0
# 26   63.000000            87.0           69.0             78.0
#
# ...

# %%
ndf.dropna(how = "all")
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0    62.000000             NaN           90.0              NaN
# 1    69.043478            74.0           87.0             81.0
# 2    65.000000            76.0           61.0             72.0
# 3    68.000000            78.0            NaN             80.0
# 4    69.043478            75.0           63.0              NaN
# 5    81.000000             NaN           58.0             70.0
# 6    78.000000            78.0            NaN             81.0
# 7    84.000000            77.0           61.0             76.0
# 8    69.043478            86.0           71.0              NaN
# 9    80.000000            87.0           85.0             71.0
# 10   77.000000             NaN            NaN             79.0
# 11   60.000000            80.0           67.0              NaN
# 12   60.000000            73.0           71.0             73.0
# 13   69.043478            83.0           50.0             77.0
# ...

# %%
ndf.dropna(axis = 1)
# Out:
#     math score  club join year  placement offer count  gender
# 0    62.000000            2018                      1    male
# 1    69.043478            2018                      2    male
# 2    65.000000            2022                      1    male
# 3    68.000000            2018                      2    male
# 4    69.043478            2021                      1    male
# 5    81.000000            2020                      1    male
# 6    78.000000            2019                      2    male
# 7    84.000000            2019                      2    male
# 8    69.043478            2023                      1    male
# 9    80.000000            2023                      1  female
# 10   77.000000            2019                      2    male
# 11   60.000000            2019                      1  female
# 12   60.000000            2022                      1    male
# 13   69.043478            2018                      2  female
# ...

# %%
new_data = ndf.dropna(axis = 0,how = 'any')
new_data
# Out:
#     math score  reading ascore  writing score  placement score  \
# 1    69.043478            74.0           87.0             81.0
# 2    65.000000            76.0           61.0             72.0
# 7    84.000000            77.0           61.0             76.0
# 9    80.000000            87.0           85.0             71.0
# 12   60.000000            73.0           71.0             73.0
# 13   69.043478            83.0           50.0             77.0
# 16   60.000000            83.0           59.0             75.0
# 17   82.000000            90.0           73.0             73.0
# 19   65.000000            83.0           82.0             77.0
# 22   63.000000            81.0           65.0             89.0
# 23   60.000000            88.0           56.0             87.0
# 24   86.000000            86.0           67.0             76.0
# 25   69.043478            88.0           70.0             71.0
# 26   63.000000            87.0           69.0             78.0
#
# ...

# %%
col = ["math score","reading ascore","writing score","placement score"]
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df["math score"]>90))
print(np.where(df["reading ascore"]<25))
print(np.where(df["writing score"]<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
df=pd.read_csv("shradha.csv")
df
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0         62.0             NaN           90.0              NaN
# 1          NaN            74.0           87.0             81.0
# 2         65.0            76.0           61.0             72.0
# 3         68.0            78.0            NaN             80.0
# 4          NaN            75.0           63.0              NaN
# 5         81.0             NaN           58.0             70.0
# 6         78.0            78.0            NaN             81.0
# 7         84.0            77.0           61.0             76.0
# 8          NaN            86.0           71.0              NaN
# 9         80.0            87.0           85.0             71.0
# 10        77.0             NaN            NaN             79.0
# 11        60.0            80.0           67.0              NaN
# 12        60.0            73.0           71.0             73.0
# 13         NaN            83.0           50.0             77.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import numpy as np

# %%
df=pd.read_csv("shradha.csv")
df
# Out:
#     math score  reading ascore  writing score  placement score  \
# 0         62.0             NaN           90.0              NaN
# 1          NaN            74.0           87.0             81.0
# 2         65.0            76.0           61.0             72.0
# 3         68.0            78.0            NaN             80.0
# 4          NaN            75.0           63.0              NaN
# 5         81.0             NaN           58.0             70.0
# 6         78.0            78.0            NaN             81.0
# 7         84.0            77.0           61.0             76.0
# 8          NaN            86.0           71.0              NaN
# 9         80.0            87.0           85.0             71.0
# 10        77.0             NaN            NaN             79.0
# 11        60.0            80.0           67.0              NaN
# 12        60.0            73.0           71.0             73.0
# 13         NaN            83.0           50.0             77.0
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
col = ["math score","reading ascore","writing score","placement score"]
df.boxplot(col)
plt.show()

# %%
print(np.where(df["math score"]>90))
print(np.where(df["reading ascore"]<25))
print(np.where(df["writing score"]<30))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
fig,ax = plt.subplots(figsize = (18,10))
ax.scatter(df["placement score"], df["placement offer count"])
plt.show()

# %%
import numpy as np
from scipy import stats

# %%
z= np.abs(stats.zscore(df['club join year']))

# %%
print(z)
# Out:
# 0     1.017700
# 1     1.017700
# 2     1.017700
# 3     1.017700
# 4     0.508850
# 5     0.000000
# 6     0.508850
# 7     0.508850
# 8     1.526551
# 9     1.526551
# 10    0.508850
# 11    0.508850
# 12    1.017700
# 13    1.017700
# 14    1.017700
# 15    1.526551
# 16    1.017700
# 17    1.017700
# 18    0.508850
# 19    1.017700
# 20    1.017700
# 21    1.017700
# 22    1.017700
# 23    0.000000
# 24    0.508850
# 25    1.526551
# 26    1.526551
# 27    1.017700
# 28    1.017700
# Name: club join year, dtype: float64

# %%
threshold = 0.18
sample_outliers = np.where(z<threshold)
sample_outliers
# Out:
# (array([ 5, 23], dtype=int64),)

# %%
sorted_rscore = sorted(df['reading ascore'])
sorted_rscore
q1 = np.percentile(sorted_rscore,5)
q3 = np.percentile(sorted_rscore,10)
print(q1,q3)
# Out:
# nan nan
